# %%
# %run ../config/setup

# %%
# %python

"""
Move the FHIR bundles to a UC volume
"""

try:
  # Move the fhir bundles
  dbutils.fs.cp(data_directory, bundle_directory, recurse=True)
except Exception as err:
  raise ValueError(f"Failed to copy bundles : {bundle_directory}, error : {err}")
